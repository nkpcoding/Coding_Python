# %%
# Introduction to Python
# Week 1
# Assignment by Nava Peter (211311147)

#### Information Organization ####

# 1. Import Packages

import pandas as pd

# 2. Dictionary Creation

data = {
  "participant_num" : [1,2,3,4,5,6], #participant number (from 1-6),
  "participant_gender" : ["male", "female", "nonbinary", "male", "female", "female"], #participant gender (male, female or nonbinary)
  "participant_age" : [25, 37, 18, 21, 32, 17], #participant age (between 15-40),
  "has_depression" : [0, 1, 1, 0, 0, 1] #whether or not the participant has depression (0 is for one who doesn't have, 1 is for one who does have)
  }

# 3. Dataset Creation

participants_df = pd.DataFrame(data)

#### Data Printing ####

print (participants_df)

#### Import to CSV ####

participants_df.to_csv("/content/drive/MyDrive/Coding/Python/Lesson_1/python_assignment_1.csv", index=False)
# Out:
#    participant_num participant_gender  participant_age  has_depression
# 0                1               male               25               0
# 1                2             female               37               1
# 2                3          nonbinary               18               1
# 3                4               male               21               0
# 4                5             female               32               0
# 5                6             female               17               1
